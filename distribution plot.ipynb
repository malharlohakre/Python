# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import seaborn as sns
df = pd.read_csv('C:/dm_office_sales.csv')
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
#distribution plot will show you the spread of the data

# %%
col = df.columns

# %%
col=type(col) #index value converted in index
# Out:
# pandas.core.indexes.base.Index

# %%
col_list = list((col))

# %%
type(col_list)
# Out:
# list

# %%
for i in range(0,len(col_list)):
    print(i,col_list[i]) # method 1 we used i loc method just to get the columns numbers
# Out:
# 0 division
# 1 level of education
# 2 training level
# 3 work experience
# 4 salary
# 5 sales

# %%
x = df.iloc[:,[4,5]]
x
# Out:
#      salary   sales
# 0     91684  372302
# 1    119679  495660
# 2     82045  320453
# 3     92949  377148
# 4     71280  312802
# ..      ...     ...
# 995   70083  177953
# 996   68648  103703
# 997  108354  450011
# 998   79035  330354
# 999  108444  364436
#
# [1000 rows x 2 columns]

# %%
x1 = df[['salary','sales']]
x1  #method here insereted the columns name
# Out:
#      salary   sales
# 0     91684  372302
# 1    119679  495660
# 2     82045  320453
# 3     92949  377148
# 4     71280  312802
# ..      ...     ...
# 995   70083  177953
# 996   68648  103703
# 997  108354  450011
# 998   79035  330354
# 999  108444  364436
#
# [1000 rows x 2 columns]

# %%
x.corr()
# Out:
#           salary     sales
# salary  1.000000  0.897376
# sales   0.897376  1.000000

# %%
sns.scatterplot(data = df,x = 'salary', y = 'sales' , hue = 'division',palette='Dark2')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
df['division'].unique()
# Out:
# array(['printers', 'peripherals', 'office supplies', 'computer hardware',
#        'computer software'], dtype=object)

# %%
'''
Rug plot 
Very simple that puts down one mark per data point.
This plot needs the single array passed in directly'''
#only one axis as it is distribution plot
sns.rugplot(x='salary',data=df)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.displot(x='salary',data=df)

# %%
sns.set(style='darkgrid')
sns.histplot(x='salary',data=df,bins=100)
#bins gives how much value you want eg 10 so it will give 10 values
#set style chnges the background
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.set(style='white')
sns.histplot(x='salary',data=df,bins=100)
#bins gives how much value you want eg 10 so it will give 10 values
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
#project
import random as rd

print("Welcome to the messanger simulation app")
message = input("Enter the message")
receivers_num = input("Enter the number of 10 digits")

numbers = [receivers_num]
while len(numbers) < 3:
    num = (rd.randint(1000000000,9999999999))
    if num not in numbers:
        numbers.append(num)

rd.shuffle(numbers)
print("The receivers phone number shows")
print("1",numbers[0])
print("2",numbers[1])
print("3",numbers[2])

choice = int(input("choose the correct number between (1-3)"))
sahi = numbers[choice- 1]
if sahi == receivers_num:
    print("message received on", sahi , message)
else:
    print("glt hai",message)
# Out:
# Welcome to the messanger simulation app
# Enter the message ]]
# Enter the number of 10 digits 5665454535453435
# The receivers phone number shows
# 1 4949645763
# 2 5665454535453435
# 3 8567881937
# choose the correct number between (1-3) 2
# message received on 5665454535453435 ]]
