# %%
#request - to fetch the website
#beautiful soup - to pass html it is used to in websites which are html coded
#regex 
#basic 2 components get and post to access the website we should you get compo bcoz it is used for URL
#parsing - it will read each and every character 
#encoding - whatever read in the website python will read it

# %%
import requests
url = "https://quotes.toscrape.com/"
response = requests.get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')

# %%
import requests
url = "https://quotes.toscrape.com/"
response = requests.get(url)
f = open("malhar_ki_file","w",encoding = 'utf-8')
f.write(response.text)
f.close()
print('the html doc is saved')
#cltr f to find keywords in notepad
# Out:
# the html doc is saved

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')
authors = soup.find_all("small",class_ = "author")
for a in authors:
    print(a.text)
print(len(authors))
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin
# 10

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')
quote = soup.find_all("span",class_ = "text")
for q in quote:
    print(q.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %%
import requests
url = "https://quotes.toscrape.com/"
response = requests.get(url)
print(response.text[:300])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">

# %%
url1 = "https://books.toscrape.com/"
reponse = requests.get(url)
f = open("mithhh_ki_file","w",encoding = 'utf-8')
f.write(response.text)
f.close()
print('the html doc is saved')
# Out:
# the html doc is saved

# %%
url1 = "https://books.toscrape.com/"
reponse = requests.get(url)
print(response.text[:300])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">

# %%
soup = BeautifulSoup(response.text,'html.parser')
title = soup.find_all("h3")
print("book titles")
for t in title:
    print(t.a["title"])
# Out:
# book titles
