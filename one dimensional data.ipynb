# %%
stock = [12,'apple',12.2,[1,2]]
print(stock)
x = ['apple','mango','jam']
x1 = 'apple','mango','jam'
print(x[2])
print(type(x[2]))
# Out:
# [12, 'apple', 12.2, [1, 2]]
# jam
# <class 'str'>

# %%
x1 = ['apple','apple','mango','mango']
p_a = 120
p_m = 100
a = 0
m = 0
for i in x1:
    if(i=='apple'):
        a+=1
    elif(i=='mango'):
        m+=1
print('final stock')
print('apple',a,p_a*a)
print('mango',m,p_m*m)
# Out:
# final stock
# apple 2 240
# mango 2 200
# ['apple', 'apple', 'mango', 'mango', 'cherry']
# ['apple', 'apple', 'strawberry', 'mango', 'mango', 'cherry']
# ['apple', 'strawberry', 'mango', 'mango']

# %%
print('hi')
# Out:
# hi

# %%
x1.append('cherry')
print(x1)
x1.insert(2,'strawberry')
print(x1)
x1.remove('apple')
x1.pop()
print(x1)
# Out:
# ['apple', 'strawberry', 'mango', 'mango', 'cherry']
# ['apple', 'strawberry', 'strawberry', 'mango', 'mango', 'cherry']
# ['strawberry', 'strawberry', 'mango', 'mango']

# %%
a = input('enter your name')
print(a,"Welcome to Malhar's shopping mart")
q1 = input('are you new user or existing. N OR E')
if (q1.lower() == 'n'):
    print('please sign up')
elif (q1.lower() == 'e'):
    q2 = input('enter your username')
    if(q2 == 'malhar'):
        q3 = int(input('enter your password'))
        if(q3 == 2004):
            print('welcome enjoy your shopping exp!')
            users = True
        s = 0
        m = 0
        l = 0
        while users:
            item = input('enter the name of the item')
            size = input('enter the size you want.s for small, m for medium, l for large')
            if size.lower() == 's':
                s +=1
            elif size.lower() == 'm':
                m +=1
            elif size.lower() == 'l':
                l +=1
            else:
                print('size not available')
            final = input(' do you want to shop more? (yes/no)')
            if final.lower() != 'yes':
                users = False
                print('Thanks for shopping')
                print('total small size',s)
                print('total medium size',m)
                print('total large size',l)
        else:
            print('Invalid Password')
    else:
        print('Invalid Username')
else:
    print('invalid entry')
# Out:
# enter your name tisha
# tisha Welcome to Malhar's shopping mart
# are you new user or existing. N OR E e
# enter your username malhar
# enter your password 2004
# welcome enjoy your shopping exp!
# enter the name of the item lip loss
# enter the size you want.s for small, m for medium, l for large m
#  do you want to shop more? (yes/no) no
# Thanks for shopping
# total small size 0
# total medium size 1
# total large size 0
# Invalid Password

# %%
x = 1234
sum = 0
while x>0:
a    x1 = x%10
    sum = sum+x1
    x = x//10
print('sum of numbers',sum)
# Out:
# sum of numbers 10

# %%
# Out:
#   File <string>:46
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
a = input('enter your name')
print(a,"Welcome to Malhar's shopping mart")
q1 = input('are you new user or existing. N OR E')
if (q1.lower() == 'n'):
    print('please sign up')
elif (q1.lower() == 'e'):
    q2 = input('enter your username')
    if(q2 == 'malhar'):
        q3 = int(input('enter your password'))
        if(q3 == 2004):
            print('welcome enjoy your shopping exp!')
            users = True
        s = 0
        m = 0
        l = 0
        shirt = 0
        jeans = 0
        jacket = 0
        shoes = 0
        while users:
            item = int(input("Press 1 to buy shirts\nPress 2 to buy jeans\nPress 3 to buy jackets\nPress 4 to buy shoes"))
            if(item == 1):
                shirt+=1
            if(item == 2):
                jeans+=1
            if(item == 3):
                jacket+=1
            if(item == 4):
                shoes+=1
            size = input('enter the size you want.s for small, m for medium, l for large')
            if size.lower() == 's':
                s +=1
            elif size.lower() == 'm':
                m +=1
            elif size.lower() == 'l':
                l +=1
            else:
                print('size not available')
            final = input(' do you want to shop more? (yes/no)')
            if final.lower() != 'yes':
                users = False
                print('Thanks for shopping')
                print('total small size',s)
                print('total medium size',m)
                print('total large size',l)
                print('total shirts',shirt)
                print('total jeans',jeans)
                print('total jackets',jacket)
                print('total shoes',shoes)
        else:
            print('Invalid Password')
    else:
        print('Invalid Username')
else:
    print('invalid entry')
# Out:
# enter your name kavita
# kavita Welcome to Malhar's shopping mart
# are you new user or existing. N OR E e
# enter your username malhar
# enter your password 2004
# welcome enjoy your shopping exp!
# Press 1 to buy shirts
# Press 2 to buy jeans
# Press 3 to buy jackets
# Press 4 to buy shoes 1
# enter the size you want.s for small, m for medium, l for large m
#  do you want to shop more? (yes/no) yes
# Press 1 to buy shirts
# Press 2 to buy jeans
# Press 3 to buy jackets
# Press 4 to buy shoes 3
# enter the size you want.s for small, m for medium, l for large l
#  do you want to shop more? (yes/no) yes
# Press 1 to buy shirts
# Press 2 to buy jeans
# Press 3 to buy jackets
# Press 4 to buy shoes 4
# enter the size you want.s for small, m for medium, l for large s
#  do you want to shop more? (yes/no) no
# Thanks for shopping
# total small size 1
# total medium size 1
# total large size 1
# total shirts 1
# total 0
# total 1
# total 1
# Invalid Password

# %%
stock = ['Apple','Mango']
price = [110,3]
item = "Apple"
qty = 4
if item in stock:
    index = stock.index(item)
    total = price[index]* qty
    print(f"item:{item}")
    print(f"unit price:{price[index]}")
    print(f"quantity: {qty}")
    print(f"total bill:{total}")
else:
    print("item not found")
# Out:
# item:Apple
# unit price:110
# quantity: 4
# total bill:440

# %%
#reverse
num1 = 45321
rev =0
while num1>0:
    digit = num1%10
    rev = rev*10+digit
    num1 = num1//10
print(rev)
# Out:
# 12354

# %%
1234%10
# Out:
# 4
