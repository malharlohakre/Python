# %%
'''An online retailer sells two products: widgets and gizmos. Each widget 
weighs 75 grams. Each gizmo weighs 112 grams. Write a program that 
reads the number of widgets and the number of gizmos in an order from 
the user. Then your program should compute and display the total weight 
of the order. '''
name = input('enter your name')
print ('hi',name,'welcome to the online store')
print ('the total weight will be in grams')
wog = 112
wow = 75
qg = int(input('How many Gizmos do you want'))
qw = int(input('how many widgets do you want'))

nwg = qg*wog
nww = qw*wow
print('The Total Weight = ',nwg+nww)
# Out:
# enter your name malhar
# hi malhar welcome to the online store
# the total weight will be in grams
# How many Gizmos do you want 8
# how many widgets do you want 9
# The Total Weight =  1571

# %%
x = 12
print(x/2)
print(x%2)
if(x%2==0):
    print('is even number')
else:
    print('is odd number')
# Out:
# 6.0
# 0
# is even number

# %%
x = float(input("enter a number"))
if(x%2==0):
    print(x,'is even')
else:
    print(x,'is odd')
# Out:
# enter a number 8
# 8.0 is even

# %%
s1 = 'my name is malhar'
print(s1)
print(len(s1))
print('There are',len(s1),'characters')
''#len func''
# Out:
# my name is malhar
# 17
# There are 17 characters

# %%
s1 = 'my name is malhar'   
print(s1)
print(len(s1))
print('There are',len(s1),'characters')
name = 'mith'
print( name in s1)
''IN funct''
# Out:
# my name is malhar
# 17
# There are 17 characters
# False

# %%
s1 = 'MY NAME IS MALHAR'   
print(s1)
print(len(s1))
print('There are',len(s1),'characters')
print(s1.lower())
print(s1.title())
print(s1[-1])
print(s1[0])
print(s1[-6:-1])
# Out:
# MY NAME IS MALHAR
# 17
# There are 17 characters
# my name is malhar
# My Name Is Malhar
# R
# M
# MALHA

# %%
s1 ='my name is mith and i am friend of malhar'
print(s1[0:2])
print(s1[-5:])
print(s1[11:])
# Out:
# my
# alhar
# mith and i am friend of malhar

# %%
#you are writing a article for a newspaper 
#codition : the article should have 10 characters
#take an input from the user in the form a string and check
#if the article can be submitted or not

# %%
article = input('Write the article')
if len(article) > 10:
    print("article submitted")
else:
    print(" article cannot be published")
# Out:
# Write the article hello my name is malhar
# article submitted
