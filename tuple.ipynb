# %%
x = (1,2,3)
x1 = tuple((6,7,8))
print(type(x))
print(type(x1))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
ladki = ['Pr','Pi','Ka','Di','Di']
ladki[2] = 'Ja'
print(ladki[2])

ladki1 = ['Pr','Pi','Ka','Di','Di']
ladki1 = list(ladki1)
ladki1[2] = 'Ja'
ladki1 = tuple(ladki)
print(ladki1[2])
# Out:
# Janvi
# Janvi

# %%
x = ['apple','tv','banana']
for i in range(0,len(x)):
    print(x[i],i)
# Out:
# apple 0
# tv 1
# banana 2

# %%
x1 = {'apple','apple','mango','mango'}
x2 = set(('apple','apple','mango','mango'))
print(type(x1))
print(type(x2))
# Out:
# <class 'set'>
# <class 'set'>

# %%
#reverse
num1 = 45321
rev =0
while num1>0:
    digit = num1%10
    rev = rev*10+digit
    num1 = num1//10
print(rev)
# Out:
# 12354

# %%
 x1 = {'apple','apple','mango','mango'}
x2 = set(('apple','apple','mango','mango'))
print(x1)
print(x2)
# Out:
# {'mango', 'apple'}
# {'mango', 'apple'}

# %%
print('hi')
# Out:
# hi

# %%
a = input('Enter your name: ')
print(a, "Welcome to Malhar's shopping mart")
shopping_list = [] 
users = True
while users:
    item = input('enter the name of the item')
    shopping_list.append(item)
    m = input('Do you want to shop more? (yes/no): ')
    if m != 'yes':
        users = False
        print('thankyou for shopping')
        print("your shopping list",shopping_list)
# Out:
# Enter your name:  malhar
# malhar Welcome to Malhar's shopping mart
# enter the name of the item mango
# Do you want to shop more? (yes/no):  yes
# enter the name of the item banana
# Do you want to shop more? (yes/no):  no
# thankyou for shopping
# your shopping list ['mango', 'banana']

# %%
a = input('Enter your name: ')
print(a, "Welcome to Malhar's shopping mart")
job = [] 
n = int(input('how many tasks are you planning'))
for i in range(0,n):
    item = input('enter the task')
    job.append(item)
print('your to do list',job)
# Out:
# Enter your name:  malhar
# malhar Welcome to Malhar's shopping mart
# how many tasks are you planning 2
# enter the task li
# enter the task wi
# your to do list ['li', 'wi']

# %%
a = input('Enter your name: ')
print(a, "Welcome to Malhar's shopping mart")
job = [] 
n = int(input('how many tasks are you planning'))
for i in range(0,n):
    item = input('enter the task')
    job.append(item)
print('your to do list',job[:2])
# Out:
# Enter your name:  malhar
# malhar Welcome to Malhar's shopping mart
# how many tasks are you planning 5
# enter the task ji
# enter the task wi
# enter the task ko
# enter the task lo
# enter the task lj
# your to do list ['ji', 'wi']

# %%
option1 = {'tomato':20, 500:'chicken'}
print(option1)
# Out:
# {'tomato': 20, 500: 'chicken'}

# %%
print(type(option1))
# Out:
# <class 'dict'>

# %%
option1['tomato']
# Out:
# 20

# %%
option1[500]
# Out:
# 'chicken'

# %%
option1 = {'🍅 ':20, 500:'chicken'}
print(option1)
# Out:
# {'🍅 ': 20, 500: 'chicken'}

# %%
option1['🍅 ']
# Out:
# 20

# %%
print('🚲 ')
# Out:
# 🚲
