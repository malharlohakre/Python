# %%
x = ['Apple',1,5,6]
import pandas as pd
x_ser = pd.Series(x)
x_ser
#this is panda serires
# Out:
# 0    Apple
# 1        1
# 2        5
# 3        6
# dtype: object

# %% [raw]
# x = ['Apple',1,5,6]
# import numpy as np
# x_arr = np.array(x)
# x_arr
# #this is numpy

# %%
x = ["Apple",1,5.7]
x_index = ['Fruit','Number','Float']
import pandas as pd
x_ser = pd.Series(data = x,index =x_index)
x_ser
# Out:
# Fruit     Apple
# Number        1
# Float       5.7
# dtype: object

# %%
month_2022 = ['Jan','Feb','March','April']
earning = [1.2,4.6,2.1,6.7]
earning_2022 = pd.Series(data = earning, index = month_2022)
earning_2022
# Out:
# Jan      1.2
# Feb      4.6
# March    2.1
# April    6.7
# dtype: float64

# %%
month_2023 = ['Jan','March','April']
earning = [1.2,2.1,6.7]
earning_2023 = pd.Series(data = earning, index = month_2023)
earning_2023
# Out:
# Jan      1.2
# March    2.1
# April    6.7
# dtype: float64

# %%
tot_earning = earning_2022 + earning_2023
tot_earning
# Out:
# April    13.4
# Feb       NaN
# Jan       2.4
# March     4.2
# dtype: float64

# %%
tot_earning_new = earning_2022.add(earning_2023,fill_value = 0)
tot_earning_new
# Out:
# April    13.4
# Feb       4.6
# Jan       2.4
# March     4.2
# dtype: float64

# %%
malhar_inc = {'Emp_name':['mike','jake','peter'],'salary':[15000,5000,6000],'car':['bugatti','ferrari','yd']}

# %%
malhar_inc_arr = pd.DataFrame(malhar_inc)
malhar_inc_arr
# Out:
#   Emp_name  salary      car
# 0     mike   15000  bugatti
# 1     jake    5000  ferrari
# 2    peter    6000       yd

# %%
st_per = pd.read_csv('C:/student.csv')
st_per
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
st_per.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              5000 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             5000 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
st_per.describe()
# Out:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     5000.000000    5000.000000  5000.000000
# mean     21.048400       75.356076      70.701924    69.546552
# std       1.989786       14.392716      17.436325    17.108996
# min      18.000000       50.010000      40.000000    40.010000
# 25%      19.000000       62.945000      55.707500    54.697500
# 50%      21.000000       75.670000      70.860000    69.485000
# 75%      23.000000       87.862500      85.760000    83.922500
# max      24.000000      100.000000      99.990000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      5000.000000  5000.000000          5000.000000      5000.00000
# mean         74.956320    74.836214            49.963720        74.78305
# std          14.404287    14.423848            28.989785        14.54243
# min          50.000000    50.000000             0.000000        50.00000
# ...

# %%
st_per
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
st_per[['Gender','Age']]
# Out:
#       Gender  Age
# 0     Female   22
# 1       Male   18
# 2       Male   24
# 3     Female   24
# 4     Female   23
# ...      ...  ...
# 4995    Male   19
# 4996    Male   19
# 4997  Female   24
# 4998    Male   23
# 4999  Female   21
#
# [5000 rows x 2 columns]

# %%
st_per.iloc[:,[0,3]]
#if you want entire column use ':' this
# Out:
#      Student_ID                       Email
# 0         S1000     student0@university.com
# 1         S1001     student1@university.com
# 2         S1002     student2@university.com
# 3         S1003     student3@university.com
# 4         S1004     student4@university.com
# ...         ...                         ...
# 4995      S5995  student4995@university.com
# 4996      S5996  student4996@university.com
# 4997      S5997  student4997@university.com
# 4998      S5998  student4998@university.com
# 4999      S5999  student4999@university.com
#
# [5000 rows x 2 columns]

# %%
Gender = st_per.iloc[:,0]
Gender
# Out:
# 0       S1000
# 1       S1001
# 2       S1002
# 3       S1003
# 4       S1004
#         ...
# 4995    S5995
# 4996    S5996
# 4997    S5997
# 4998    S5998
# 4999    S5999
# Name: Student_ID, Length: 5000, dtype: object

# %%
f = 0
m = 0
mal = st_per['Gender']
for i in mal:
    if(i=='Female'):
        f+=1
    else:
        m+=1
print('males',m)
print('females',f)
#m = st_per['Gender'] ye likha kyu ki ye variable nahi tha m variable hai
# Out:
# males 2551
# females 2449

# %%
mal.value_counts()
# Out:
# Gender
# Male      2551
# Female    2449
# Name: count, dtype: int64

# %%
mal.unique()
# Out:
# array(['Female', 'Male'], dtype=object)
